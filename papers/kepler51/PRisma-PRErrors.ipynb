# %%
import numpy as np

# %%
rho_true = 2

rhos_info = [
    [2.441,+0.0573,-0.073], 
    [2.171,+0.158,-0.147],
    [2.160,+0.150,-0.130],
    [2.420,+0.060,-0.060],
    [2.560,+0.423,-0.347]
]

# %%
for rho_info in rhos_info:
    rho = rho_info[0]
    drho = (abs(rho_info[1])+abs(rho_info[2]))/2
    PR = 10*np.log10(rho/2)
    dPR = 10/np.log(10)*drho/rho
    print(np.round(PR,2), np.round(dPR,2))
# Out:
# 0.87 0.12
# 0.36 0.31
# 0.33 0.28
# 0.83 0.11
# 1.07 0.65

# %%
Mearth = 5.97e24 # kg
Rsun = 6.96e8 # m

Mb = 6.9 * Mearth  # Masuda+2024 Outside 2:1
Md = 6.9 * Mearth

Rstar = 0.869 * Rsun
Rb = 0.07225 * Rstar
Rd = 0.09857 * Rstar

rhob = Mb / (4/3 * np.pi * Rb**3)
rhod = Md / (4/3 * np.pi * Rd**3)

rhob / 1e3 , rhod / 1e3
# Out:
# (0.11785125456759095, 0.04641020585104052)
